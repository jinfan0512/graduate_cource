# %%
import glob
import os
import sys
import timeit
import matplotlib
import matplotlib.backends.backend_pdf 
import numpy as np
from PyQSOFit import QSOFit
from astropy.io import fits
import matplotlib.pyplot as plt
import warnings
import sys
import math
import codecs
# -*- coding: utf-8 -*-
sys.setrecursionlimit(100000)#Depth of return
warnings.filterwarnings("ignore")

path='./'#当前目录下

# %%
newdata = np.rec.array([(6564.61,'Ha',6400.,6800.,'Ha_br',3,6e-3,0.004,0.05,0.015,0,0,0,0.05),\
                                                (6564.61,'Ha',6400.,6800.,'Ha_na',1,4e-4,1e-4,0.0017,0.01,1,1,0,0.002),\
                                                (6549.85,'Ha',6400.,6800.,'NII6549',1,4e-4,2.3e-4,0.0017,5e-3,1,1,3,0.001),\
                                                (6585.28,'Ha',6400.,6800.,'NII6585',1,4e-4,2.3e-4,0.0017,5e-3,1,1,3,0.003),\
                                                (6718.29,'Ha',6400.,6800.,'SII6718',1,4e-4,2.3e-4,0.0017,5e-3,1,2,0,0.001),\
                                                (6732.67,'Ha',6400.,6800.,'SII6732',1,4e-4,2.3e-4,0.0017,5e-3,1,2,0,0.001),\
                                                
                                                (4862.68,'Hb',4640.,5100.,'Hb_br',3,5e-3,0.004,0.05,0.01,0,0,0,0.01),\
                                                (4862.68,'Hb',4640.,5100.,'Hb_na',1,1e-3,2.3e-4,0.0017,0.01,1,1,0,0.002),\
                                                (4960.30,'Hb',4640.,5100.,'OIII4959c',1,1e-3,2.3e-4,0.0017,0.01,1,1,1,0.002),\
                                                (5008.24,'Hb',4640.,5100.,'OIII5007c',1,1e-3,2.3e-4,0.0017,0.01,1,1,1,0.006),\
                                                (4960.30,'Hb',4640.,5100.,'OIII4959w',2,3e-3,2.3e-4,0.004,0.01,1,1,2,0.001),\
                                                (5008.24,'Hb',4640.,5100.,'OIII5007w',2,3e-3,2.3e-4,0.004,0.01,1,1,2,0.002),\
                                                #(4687.02,'Hb',4640.,5100.,'HeII4687_br',1,5e-3,0.004,0.05,0.005,0,0,0,0.001),\
                                                #(4687.02,'Hb',4640.,5100.,'HeII4687_na',1,1e-3,2.3e-4,0.0017,0.005,1,1,0,0.001),\
                                                
                                                #(3934.78,'CaII',3900.,3960.,'CaII3934',2,1e-3,3.333e-4,0.0017,0.01,99,0,0,-0.001),\
                                                
                                                #(3728.48,'OII',3650.,3800.,'OII3728',1,1e-3,3.333e-4,0.0017,0.01,1,1,0,0.001),\
                                                
                                                #(3426.84,'NeV',3380.,3480.,'NeV3426',1,1e-3,3.333e-4,0.0017,0.01,0,0,0,0.001),\
                                                #(3426.84,'NeV',3380.,3480.,'NeV3426_br',1,5e-3,0.0025,0.02,0.01,0,0,0,0.001),\
                                                
                                                #(2798.75,'MgII',2700.,2900.,'MgII_br',1,5e-3,0.004,0.05,0.015,0,0,0,0.05),\
                                                #(2798.75,'MgII',2700.,2900.,'MgII_na',1,1e-3,5e-4,0.0017,0.01,1,1,0,0.002),\
                                                
                                                #(1908.73,'CIII',1700.,1970.,'CIII_br',2,5e-3,0.004,0.05,0.015,99,0,0,0.01),\
                                                #(1908.73,'CIII',1700.,1970.,'CIII_na',1,1e-3,5e-4,0.0017,0.01,1,1,0,0.002),\
                                                #(1892.03,'CIII',1700.,1970.,'SiIII1892',1,2e-3,0.001,0.015,0.003,1,1,0,0.005),\
                                                #(1857.40,'CIII',1700.,1970.,'AlIII1857',1,2e-3,0.001,0.015,0.003,1,1,0,0.005),\
                                                #(1816.98,'CIII',1700.,1970.,'SiII1816',1,2e-3,0.001,0.015,0.01,1,1,0,0.0002),\
                                                #(1786.7,'CIII',1700.,1970.,'FeII1787',1,2e-3,0.001,0.015,0.01,1,1,0,0.0002),\
                                                #(1750.26,'CIII',1700.,1970.,'NIII1750',1,2e-3,0.001,0.015,0.01,1,1,0,0.001),\
                                                #(1718.55,'CIII',1700.,1900.,'NIV1718',1,2e-3,0.001,0.015,0.01,1,1,0,0.001),\
                                                
                                                #(1549.06,'CIV',1500.,1700.,'CIV_br',1,5e-3,0.004,0.05,0.015,0,0,0,0.05),\
                                                #(1549.06,'CIV',1500.,1700.,'CIV_na',1,1e-3,5e-4,0.0017,0.01,1,1,0,0.002),\
                                                #(1640.42,'CIV',1500.,1700.,'HeII1640',1,1e-3,5e-4,0.0017,0.008,1,1,0,0.002),\
                                                #(1663.48,'CIV',1500.,1700.,'OIII1663',1,1e-3,5e-4,0.0017,0.008,1,1,0,0.002),\
                                                #(1640.42,'CIV',1500.,1700.,'HeII1640_br',1,5e-3,0.0025,0.02,0.008,1,1,0,0.002),\
                                                #(1663.48,'CIV',1500.,1700.,'OIII1663_br',1,5e-3,0.0025,0.02,0.008,1,1,0,0.002),\
                                                
                                                #(1402.06,'SiIV',1290.,1450.,'SiIV_OIV1',1,5e-3,0.002,0.05,0.015,1,1,0,0.05),\
                                                #(1396.76,'SiIV',1290.,1450.,'SiIV_OIV2',1,5e-3,0.002,0.05,0.015,1,1,0,0.05),\
                                                #(1335.30,'SiIV',1290.,1450.,'CII1335',1,2e-3,0.001,0.015,0.01,1,1,0,0.001),\
                                                #(1304.35,'SiIV',1290.,1450.,'OI1304',1,2e-3,0.001,0.015,0.01,1,1,0,0.001),\
                                                
                                                #(1215.67,'Lya',1150.,1290.,'Lya_br',1,5e-3,0.004,0.05,0.02,0,0,0,0.05),\
                                                #(1215.67,'Lya',1150.,1290.,'Lya_na',1,1e-3,5e-4,0.0017,0.01,0,0,0,0.002)\
                                                ],\
                                         formats='float32,a20,float32,float32,a20,float32,float32,float32,float32,\
                                         float32,float32,float32,float32,float32',\
                                         names='lambda,compname,minwav,maxwav,linename,ngauss,inisig,minsig,maxsig,voff,vindex,windex,findex,fvalue')
                                                #波长，名字，最小波长，最大波长，线的名字，几个高斯拟合....）

# %%
hdr = fits.Header()
hdr['lambda'] = 'Vacuum Wavelength in Ang'
hdr['minwav'] = 'Lower complex fitting wavelength range'
hdr['maxwav'] = 'Upper complex fitting wavelength range'
hdr['ngauss'] = 'Number of Gaussians for the line'
hdr['inisig'] = 'Initial guess of linesigma [in lnlambda]'
hdr['minsig'] = 'Lower range of line sigma [lnlambda]'  
hdr['maxsig'] = 'Upper range of line sigma [lnlambda]'
hdr['voff  '] = 'Limits on velocity offset from the central wavelength [lnlambda]'
hdr['vindex'] = 'Entries w/ same NONZERO vindex constrained to have same velocity'
hdr['windex'] = 'Entries w/ same NONZERO windex constrained to have same width'
hdr['findex'] = 'Entries w/ same NONZERO findex have constrained flux ratios'
hdr['fvalue'] = 'Relative scale factor for entries w/ same findex'

# %%
hdu = fits.BinTableHDU(data=newdata,header=hdr,name='data')
hdu.writeto(path+'qsopar.fits',overwrite=True)

path1='./' #'/Users/legolason/study/mesfit/'                  # the path of the source code file and qsopar.fits
path2=path1+'result-dong/' #'/Users/legolason/study/mesfit/test/data/result/' # path of fitting results 可以修改  需新建
path3=path1+'result-dong/' #'/Users/legolason/study/mesfit/test/data/QA_l/'   # path of figure          可以修改  需新建
path4=path1+'dustmap/' #'/Users/legolason/study/sed/dustmap/'             # path of dusp reddening map  可以修改  需新建
path5=path1+'pdfresult/' #for pdf fitting result figure                                     需要新建一个文件夹   可以修改
#Requried
# an important note that all the data input must be finite, especically for the error !!!

filename=glob.glob(r'./specdong12/specdong12/*.fits') ## fits file for fitting
n=len(filename)   #总数

n2=1   # 一次几个
n1=int(n/n2)

n3=2  # 一共几组

a=[]
data_list=[0,0,0,0,0,0]
data_list2=[0,0,0,0,0,0]
for i in range(0,n3):
        pdf = matplotlib.backends.backend_pdf.PdfPages(path5+'output'+str(i)+'.pdf')
        if i < n1:
           filename1=filename[i*n2:(i+1)*n2]
        else:
           filename1=filename[i*n2:n]
                        
        for pathname in filename1:
                data=fits.open(pathname) 
                lam=10**data[1].data['loglam']        # OBS wavelength [A]
                flux=data[1].data['flux']             # OBS flux [erg/s/cm^2/A]
                err=1./np.sqrt(data[1].data['ivar'])  # 1 sigma error
                z=data[2].data['z'][0]                # Redshift

        #Optinal
                ra=data[0].header['plug_ra']          # RA 
                dec=data[0].header['plug_dec']        # DEC
                plateid = data[0].header['plateid']   # SDSS plate ID
                mjd = data[0].header['mjd']           # SDSS MJD
                fiberid = data[0].header['fiberid']   # SDSS fiber ID
                name=str(plateid).zfill(4)+'-'+str(mjd)+'-'+str(fiberid).zfill(4)
                print (name)
        # get data prepared 
                
                q = QSOFit(lam, flux, err, z, ra = ra, dec = dec, plateid = plateid, mjd = mjd, fiberid = fiberid, path = path1)
        # do the fitting                                                                                    wave_range 是可修改的
                fig_one=q.Fit(name = None,nsmooth = 2, and_or_mask = False, deredden = True, reject_badpix = False, wave_range =None,\
                                  wave_mask =None, decomposition_host = True, Mi = None, npca_gal = 10, npca_qso = 20, \
                                  Fe_uv_op = True, poly = True, BC = True, rej_abs = False, initial_guess = None, MC = False, \
                                  n_trails = 5, linefit = True, tie_lambda = True, tie_width = True, tie_flux_1 = True, tie_flux_2 = True,\
                                  save_result = True, plot_fig = True,save_fig = True, plot_line_name = True, plot_legend = True, \
                                  dustmap_path = path4, save_fig_path = path3, save_fits_path = path2,save_fits_name = name)

# %%
 #get fwhm etc.
                #we need to change the type of ndarray from 'u32' to 'float64',because of the function"'line_prop':ind_br = np.repeat(np.where(pp[2::3]> 0.0017,True,False),3)' " 0.0017 is float num.
                #we can see the type with'>>> q.line_result[36:39].dtype'
                #for further information,see log0413
                print (np.array(q.linelist[1][0]))
                print (q.line_result_name[42:51])#changeable
                l_result=np.array(q.line_result[42:51])
                l_list=np.array(q.linelist[1][0])
                l_result_float=l_result.astype(np.float64)
                l_list_float=l_list.astype(np.float64)  
                fwhm,sigma,ew,peak,area = q.line_prop(6564,l_result_float)
                if area!=0:
                    area_log=math.log(area,10)-17
                else:
                    area_log=0
                data_list=[0,0,0,0,0,0]
                data_list[0]=name
                data_list[1]=fwhm
                data_list[2]=q.line_result[-5]
                data_list[3]=area_log
                data_list[4]=ra
                data_list[5]=dec
                #data_list[]=q.line_result[-1]
                print("Hb_baoad:")
                print("fwhm(km/s):", fwhm)
                print ('fwhm_whole(km/s):',q.line_result[-5])
                #print("Sigma (km/s)", sigma)
                #print("EW (A)",ew)
                #print ('peak',peak)
                #print ('area:',area)
                print("area (10^(-17) erg/s/cm^2):",area_log)
                print('ra:',ra)
                print('de:',dec)
                #print ('area_whole:',q.line_result[-1])
                data_list2.append(str(data_list[0:6])+'\r\n')
                     
                
        if  q.decomposed == False:
                q.host=np.zeros_like(q.wave)      
                c1 = fits.Column(name='wave', array=q.wave, format='E')
                c2 = fits.Column(name='conti', array=q.f_conti_model, format='E')
                c3 = fits.Column(name='host', array=q.host, format='E')
                c4 = fits.Column(name='poly', array=q.f_poly_model, format='E')
                c5 = fits.Column(name='power law', array=q.f_pl_model, format='E')
                c6 = fits.Column(name='fe UV', array=q.f_fe_uv_model, format='E')
                c7 = fits.Column(name='fe opt', array=q.f_fe_op_model, format='E')
                c8 = fits.Column(name='balmer conti', array=q.f_bc_model, format='E')
                c9 = fits.Column(name='flux', array=q.flux, format='E')
                c10=fits.Column(name='emission lines', array=q.Manygauss(np.log(q.wave),q.gauss_result), format='E')   #   print q.Manygauss(np.log(q.wave),q.gauss_result)
#write fitting model and emission line  data to fits file     
 
                t = fits.BinTableHDU.from_columns([c1, c2, c3, c4, c5, c6,c7, c8, c9,c10])
                t.writeto(path2+name+'-m.fits',overwrite=True) 
                fits.setval(path2+name+'-m.fits', 'Z', value=str(z))
                pdf.savefig( fig_one )

        pdf.close()
        

        end = timeit.default_timer()
        print ('Fitting finished in:' +str(np.round(end-start))+'s')
# grey shade on the top is the continuum windiows used to fit.
print (data_list2)
txt=codecs.open('test.txt','w')
txt.write(str(data_list2))
txt.write('3 components fitting')
txt.close()
